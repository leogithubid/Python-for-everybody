# %%
import urllib.request,urllib.parse,urllib.error
file = urllib.request.urlopen('http://data.pr4e.org/romeo.txt')
for line in file:
    print(line.decode().strip())
# Out:
# But soft what light through yonder window breaks
# It is the east and Juliet is the sun
# Arise fair sun and kill the envious moon
# Who is already sick and pale with grief

# %%
import urllib.request,urllib.parse,urllib.error
file = urllib.request.urlopen('https://en.wikipedia.org/wiki/Haruki_Murakami#Biography')
for line in file:
    print(line.decode().strip())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>Haruki Murakami - Wikipedia</title>
# ...

# %%
import urllib.request,urllib.parse,urllib.error
file = urllib.request.urlopen('http://data.pr4e.org/romeo.txt')
counts = dict()
for line in file:
    words = line.decode().split()
    for word in words:
        counts[word] = counts.get(word,0)+1
print(counts)
# Out:
# {'But': 1, 'soft': 1, 'what': 1, 'light': 1, 'through': 1, 'yonder': 1, 'window': 1, 'breaks': 1, 'It': 1, 'is': 3, 'the': 3, 'east': 1, 'and': 3, 'Juliet': 1, 'sun': 2, 'Arise': 1, 'fair': 1, 'kill': 1, 'envious': 1, 'moon': 1, 'Who': 1, 'already': 1, 'sick': 1, 'pale': 1, 'with': 1, 'grief': 1}

# %%
import urllib.request,urllib.parse,urllib.error
from bs4 import BeautifulSoup

# %%
url = input('Enter url:')
html = urllib.request.urlopen(url).read()#read entire page
soup = BeautifulSoup(html,'html.parser')#parse the html
#Retrieve all of anchor tags
tags = soup('a')#get all anchor tags
for tag in tags:
    print(tag.get('href',None))
# Out:
# Enter url:http://data.pr4e.org
# ?C=N;O=D
# ?C=M;O=A
# ?C=S;O=A
# ?C=D;O=A
# authors.txt
# clown.txt
# cover.jpg
# cover3.jpg
# intro-short.txt
# intro.txt
# mbox-short.txt
# mbox.txt
# page1.htm
# page2.htm
# romeo-full.txt
# romeo.txt
# words.txt

# %%
import urllib.request,urllib.parse,urllib.error
from bs4 import BeautifulSoup
import ssl

# %%
#ssl certificate errors - ignore
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

# %%
url = input('Enter url:')
html = urllib.request.urlopen(url, context = ctx).read()#read entire page
soup = BeautifulSoup(html,'html.parser')#parse the html
#Retrieve all of anchor tags
tags = soup('a')#get all anchor tags
for tag in tags:
    print(tag.get('href',None))

# %%
import urllib.request,urllib.parse,urllib.error
x = urllib.request.urlopen('http://data.pr4e.org/romeo.txt')
print(type(x))
# Out:
# <class 'http.client.HTTPResponse'>

# %%
import socket

mysock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
mysock.connect(('data.pr4e.org', 80))
cmd = 'GET http://data.pr4e.org/romeo.txt HTTP/1.0\n\n'.encode()
mysock.send(cmd)

while True:
    data = mysock.recv(512)
    if (len(data) < 1):
        break
    print(data.decode())
mysock.close()
# Out:
# HTTP/1.1 400 Bad Request
# Date: Fri, 04 Feb 2022 04:08:12 GMT
# Server: Apache/2.4.18 (Ubuntu)
# Content-Length: 308
# Connection: close
# Content-Type: text/html; charset=iso-8859-1
#
# <!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">
# <html><head>
# <title>400 Bad Request</title>
# </head><body>
# <h1>Bad Request</h1>
# <p>Your browser sent a request that this server could not understand.<br />
# </p>
# <hr>
# <address>Apache/2.4.18 (Ubuntu) Server at do1.dr-chuck.com Port 80</address>
# </body></html>

# %% [markdown]
# # Assignment

# %%
# To run this, download the BeautifulSoup zip file
# http://www.py4e.com/code3/bs4.zip
# and unzip it in the same directory as this file

from urllib.request import urlopen
from bs4 import BeautifulSoup
import ssl

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

url = input('Enter - ')
html = urlopen(url, context=ctx).read()
soup = BeautifulSoup(html, "html.parser")

total = 0
# Retrieve all of the anchor tags
tags = soup('span')
for tag in tags:
    #print('Contents:', tag.contents[0])-just to check each line
    total = total + int(tag.contents[0])
    
#print total
print(total)
# Out:
# Enter - http://py4e-data.dr-chuck.net/comments_1479661.html
# 2470

# %%
# To run this, download the BeautifulSoup zip file
# http://www.py4e.com/code3/bs4.zip
# and unzip it in the same directory as this file

import urllib.request, urllib.parse, urllib.error
from bs4 import BeautifulSoup
import ssl

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

#prompt user to enter url
url = input('Enter url:')
count = int(input('Enter count:'))
position = int(input('Enter position:'))

#outer loop
j = 0
#repeat this 'count' times
while j < count:
    #read the url
    html = urllib.request.urlopen(url, context=ctx).read()
    #parse the html
    soup = BeautifulSoup(html, 'html.parser')

    # Retrieve all of the anchor tags
    tags = soup('a')
    #for inner loop
    i = 1
    #iterate through the tags
    for tag in tags:
        #repat this 'position' times
        while i == position:
            #print the url at the 'position'
            url = tag.get('href',None)
            print(url)
            j = j + 1#increase outer loop by one
            break #then jump out
        i = i + 1#increase inner loop by one
# Out:
# Enter url:http://py4e-data.dr-chuck.net/known_by_Sher.html
# Enter count:7
# Enter position:18
# http://py4e-data.dr-chuck.net/known_by_Rowanna.html
# http://py4e-data.dr-chuck.net/known_by_Tayyab.html
# http://py4e-data.dr-chuck.net/known_by_Rayaan.html
# http://py4e-data.dr-chuck.net/known_by_Dyllon.html
# http://py4e-data.dr-chuck.net/known_by_Dhavid.html
# http://py4e-data.dr-chuck.net/known_by_Tiana.html
# http://py4e-data.dr-chuck.net/known_by_Kamaljit.html

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import ssl

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

url = input('Enter - ')
html = urlopen(url, context=ctx).read()
soup = BeautifulSoup(html, "html.parser")
                     
#Retrieve all of anchor tags
tags = soup('a')#get all anchor tags
for tag in tags:
    print(tag.get('href',None))
# Out:
# Enter - https://en.wikipedia.org/wiki/Noam_Chomsky
# None
# /wiki/Wikipedia:Good_articles
# /wiki/Wikipedia:Protection_policy#semi
# /wiki/Wikipedia:Pending_changes
# https://en.wikipedia.org/w/index.php?title=Special:Log&type=review&page=Noam_Chomsky
# #mw-head
# #searchInput
# /wiki/Chomsky_(disambiguation)
# /wiki/File:Noam_Chomsky_portrait_2017_retouched.png
# /wiki/Philadelphia
# /wiki/Pennsylvania
# /wiki/Carol_Chomsky
# /wiki/Aviva_Chomsky
# /wiki/William_Chomsky
# /wiki/Guggenheim_Fellowship
# /wiki/Member_of_the_National_Academy_of_Sciences
# /wiki/APA_Award_for_Distinguished_Scientific_Contributions_to_Psychology
# /wiki/Orwell_Award
# /wiki/Kyoto_Prize_in_Basic_Sciences
# /wiki/Helmholtz_Medal
# /wiki/Benjamin_Franklin_Medal_(Franklin_Institute)
# /wiki/Sydney_Peace_Prize
# /wiki/Nuclear_Age_Peace_Foundation
# /wiki/University_of_Pennsylvania
# /wiki/Bachelor_of_Arts
# /wiki/Master_of_Arts
# /wiki/Thesis
# http://repository.upenn.edu/dissertations/AAI0013380/
# ...

# %% [markdown]
# # Previous Chapter for reference

# %%
#create socket object
mysock = socket.socket(socket.AF_INET,socket.SOCK_STREAM)
mysock.connect(('data.pr4e.org', 80))#connect to webserver port 80

# %%
cmd = 'GET http://data.pr4e.org/romeo.txt HTTP/1.0\r\n\r\n'.encode()#command - the last part
#means enter enter - look at telnet in the terminal
#encode converts Unicode to UTF-8
mysock.send(cmd)#send the command to web server
# Out:
# 47

# %%
while True:
    data = mysock.recv(512)#receive upto 512 characters
    if(len(data)<1):
        break
    print(data.decode())
mysock.close()
# Out:
# HTTP/1.1 200 OK
# Date: Fri, 04 Feb 2022 00:30:48 GMT
# Server: Apache/2.4.18 (Ubuntu)
# Last-Modified: Sat, 13 May 2017 11:22:22 GMT
# ETag: "a7-54f6609245537"
# Accept-Ranges: bytes
# Content-Length: 167
# Cache-Control: max-age=0, no-cache, no-store, must-revalidate
# Pragma: no-cache
# Expires: Wed, 11 Jan 1984 05:00:00 GMT
# Connection: close
# Content-Type: text/plain
#
# But soft what light through yonder window breaks
# It is the east and Juliet is the sun
# Arise fair sun and kill the envious moon
# Who is already s
# ick and pale with grief

# %%
#create socket object
mysock = socket.socket(socket.AF_INET,socket.SOCK_STREAM)
mysock.connect(('data.pr4e.org', 80))#connect to webserver port 80
cmd = 'GET http://data.pr4e.org/page1.htm HTTP/1.0\r\n\r\n'.encode()#command
mysock.send(cmd)#send the command to web server
while True:
    data = mysock.recv(512)#receive upto 512 characters
    if(len(data)<1):
        break
    print(data.decode())
mysock.close()
# Out:
# HTTP/1.1 200 OK
# Date: Fri, 04 Feb 2022 00:36:17 GMT
# Server: Apache/2.4.18 (Ubuntu)
# Last-Modified: Mon, 15 May 2017 11:11:47 GMT
# ETag: "80-54f8e1f004857"
# Accept-Ranges: bytes
# Content-Length: 128
# Cache-Control: max-age=0, no-cache, no-store, must-revalidate
# Pragma: no-cache
# Expires: Wed, 11 Jan 1984 05:00:00 GMT
# Connection: close
# Content-Type: text/html
#
# <h1>The First Page</h1>
# <p>
# If you like, you can switch to the
# <a href="http://data.pr4e.org/page2.htm">
# Second Page</a>.
# </p>

# %% [markdown]
# # Assignment

# %%
import socket

mysock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
mysock.connect(('data.pr4e.org', 80))
cmd = 'GET http://data.pr4e.org/intro-short.txt HTTP/1.0\r\n\r\n'.encode()
mysock.send(cmd)

while True:
    data = mysock.recv(512)
    if len(data) < 1:
        break
    print(data.decode(),end='')

mysock.close()
# Out:
# HTTP/1.1 200 OK
# Date: Fri, 04 Feb 2022 00:59:26 GMT
# Server: Apache/2.4.18 (Ubuntu)
# Last-Modified: Sat, 13 May 2017 11:22:22 GMT
# ETag: "1d3-54f6609240717"
# Accept-Ranges: bytes
# Content-Length: 467
# Cache-Control: max-age=0, no-cache, no-store, must-revalidate
# Pragma: no-cache
# Expires: Wed, 11 Jan 1984 05:00:00 GMT
# Connection: close
# Content-Type: text/plain
#
# Why should you learn to write programs?
#
# Writing programs (or programming) is a very creative
# and rewarding activity.  You can write programs for
# many reasons, ranging from making your living to solving
# a difficult data analysis problem to having fun to helping
# someone else solve a problem.  This book assumes that
# everyone needs to know how to program, and that once
# you know how to program you will figure out what you want
# to do with your newfound skills.

# %%
#en.wikipedia.org/wiki/Main_Page
import socket

mysock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
mysock.connect(('en.wikipedia.org', 80))
cmd = 'GET http://en.wikipedia.org/wiki/Main_Page.html HTTP/1.0\r\n\r\n'.encode()
mysock.send(cmd)

while True:
    data = mysock.recv(512)
    if len(data) < 1:
        break
    print(data.decode(),end='')

mysock.close()
# Out:
# HTTP/1.1 301 TLS Redirect
# Date: Fri, 04 Feb 2022 01:07:39 GMT
# Server: Varnish
# X-Varnish: 247001368
# X-Cache: cp5015 int
# X-Cache-Status: int-front
# Server-Timing: cache;desc="int-front", host;desc="cp5015"
# Permissions-Policy: interest-cohort=()
# Set-Cookie: WMF-Last-Access=04-Feb-2022;Path=/;HttpOnly;secure;Expires=Tue, 08 Mar 2022 00:00:00 GMT
# Set-Cookie: WMF-Last-Access-Global=04-Feb-2022;Path=/;Domain=.wikipedia.org;HttpOnly;secure;Expires=Tue, 08 Mar 2022 00:00:00 GMT
# X-Client-IP: 49.186.51.103
# Location: https://en.wikipedia.org/wiki/Main_Page.html
# Content-Length: 0
# Connection: close
